# %% [markdown]
# <a href="https://colab.research.google.com/github/GonzalezMart2019/MathData24/blob/main/MathData_Class1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Notes

# %%
<img src="https://365datascience.com/resources/blog/thumb@1024_u19rtmtc4a-data-engineer-vs-data-scientist-salaries.webp">
# Out:
#   File "<ipython-input-21-4a19d6152a89>", line 1
#     <img src="https://365datascience.com/resources/blog/thumb@1024_u19rtmtc4a-data-engineer-vs-data-scientist-salaries.webp">
#     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
A = np.random.random((1,5))
A
# Out:
# array([[0.94724194, 0.39932728, 0.32404037, 0.33066395, 0.05041549]])

# %%
B = np.random.random((1,5))
B
# Out:
# array([[0.89805144, 0.656047  , 0.05502544, 0.5939846 , 0.97192381]])

# %%
A = A.T
B = B.T

# %%
plt.plot(A,B)

# %%
plt.plot(A,B, 'r.')

# %%
X = np.random.random((100,1))
Y = np.random.random((100,1))
plt.plot(X,Y, 'g--')

# %%
print(A.shape,B.shape,X.shape,Y.shape)
# Out:
# (5, 1) (5, 1) (100, 1) (100, 1)

# %%
Z = np.random.random((100,100))
Z.shape
# Out:
# (100, 100)

# %%
plt.imshow(Z)
